# %%
import pandas as pd
import numpy as np

# %%
# dont use modified_data_v3_item_imputed.csv, instead use v6

# %%
df = pd.read_csv('modified_data_v2.csv')

# %%
df[df['transaction_date'] < 62][['shop_id', 'shop_profile', 'transaction_date']]
# Out:
#     shop_id shop_profile  transaction_date
# 24  SHOP120          Low                60
# 48  SHOP055     Moderate                55
# 51  SHOP008     Moderate                 6
# 79  SHOP112     Moderate                61

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
# df = df.iloc[:,:-10]

# %%
df.head()
# Out:
#    shop_id  shop_area_sq_ft shop_profile  quantity_sold  tot_sales_amount  \
# 0  SHOP047              528     Moderate           1692            842960
# 1  SHOP009              676         High           4589           1970870
# 2  SHOP083              676          Low           3614           1691985
# 3  SHOP117              676          Low           4074           2325980
# 4  SHOP042              676          Low           3272           1340215
#
#    customer_id  invoice_id  transaction_date  BOTTLED DRINKING WATER 1.5L  \
# 0          928        1302                62                           42
# 1         2498        3493                62                          123
# 2         1900        2718                62                           81
# 3         2037        3158                62                          116
# 4         1841        2495                62                           91
#
#    BOTTLED DRINKING WATER 500ML  CHOCOLATE MILK 180ML  CREAM SODA 1.5L  \
# 0                           124                     0              249
# 1                           427                     0              686
# 2                           256                     3              592
# 3                           152                     0              565
# 4                           228                     0              478
#
#    CREAM SODA 1L  CREAM SODA 500ML  CREAM SODA APPLE POP 1L  \
# 0             28               278                       71
# 1             62               451                      203
# 2             76               408                      186
# 3             58               343                      318
# 4             40               385                      138
#
#    DRY GINGER ALE PET 500ML  FIT O MANGO 1L  FIT O MANGO 200ML  \
# 0                         8              66                 87
# 1                        56              76                102
# 2                        67              93                 89
# 3                       155             115                166
# 4                        74              98                 66
#
#    FIT O MIXED FRUIT 1L  FIT O MIXED FRUIT 200ML  FIT O ORANGE 1L  \
# 0                    31                       44               66
# 1                   115                      182              208
# 2                    95                       92              211
# 3                   110                      188              216
# 4                    67                       53              183
#
#    FIT O ORANGE 200ML  GINGER BEER 1.5L  GINGER BEER 1L  GINGER BEER 400ML  \
# 0                 137               306             189                 51
# 1                 223              1018             552                 69
# 2                 172               734             559                 29
# 3                 150               797             468                 56
# 4                 142               666             467                 47
#
#    GINGER BEER 500ML  GINGER BEER SUGAR FREE 500ML  KIK COLA 1L  \
# 0                 84                            26            7
# 1                254                            96           30
# 2                122                            67           43
# 3                 81                            85           72
# 4                147                            68           25
#
#    LEMONADE 1.5L  LEMONADE 1L  LEMONADE 500ML  LIME CRUSH JUICE 1L  \
# 0             41           19              31                    0
# 1            194           15             113                    0
# 2            168           15              63                    0
# 3            182           30              57                    0
# 4            131           34              57                    0
#
#    NECTO 1.5L  NECTO 1L  NECTO 500ML  ORANGE BARLEY 1.5L  ORANGE CRUSH 1.5L  \
# 0         102         6           25                 113                 59
# 1         338        24           79                 333                175
# 2         286        29           40                 359                134
# 3         402        10           45                 339                 82
# 4         178         7           26                 265                 77
#
#    ORANGE CRUSH 1L  ORANGE CRUSH 500ML  SODA 1L  SODA 500ML  SODA PET 1.5L  \
# 0               47                  39       88          60            126
# 1               17                 109      145         219            144
# 2               27                  55      151         162            160
# 3               49                  58      449         418            513
# 4               18                  46      143         211            165
#
#    STRAWBERRY MILK 180ML  TONIC PET 500ML  TWISTEE APPLE 1L
# 0                     52              116                30
# 1                     67              135                51
# 2                    109              117                48
# 3                     98              390                43
# 4                    125              140                48

# %%
df.iloc[100:].head()
# Out:
#      shop_id  shop_area_sq_ft shop_profile  quantity_sold  tot_sales_amount  \
# 100  SHOP046              545          NaN           3438           2607865
# 101  SHOP024              676          NaN           2883           1308795
# 102  SHOP023              617          NaN           4103           2570425
# 103  SHOP097              310          NaN           3148           2642380
# 104  SHOP044              715          NaN           2641           1310440
#
#      customer_id  invoice_id  transaction_date  BOTTLED DRINKING WATER 1.5L  \
# 100         1736        2735                62                          294
# 101         1641        2302                62                          224
# 102         2227        3138                62                          118
# 103         1669        2436                62                          189
# 104         1552        2082                62                           72
#
#      BOTTLED DRINKING WATER 500ML  CHOCOLATE MILK 180ML  CREAM SODA 1.5L  \
# 100                           742                     0              688
# 101                           264                     0              516
# 102                           189                     2              982
# 103                           314                     0              301
# 104                            21                     0              365
#
#      CREAM SODA 1L  CREAM SODA 500ML  CREAM SODA APPLE POP 1L  \
# 100             49               351                      124
# 101             50               390                       73
# 102             63               571                      169
# 103              0               296                       97
# 104             20               277                       64
#
#      DRY GINGER ALE PET 500ML  FIT O MANGO 1L  FIT O MANGO 200ML  \
# 100                        51              64                 85
# 101                        72              76                 66
# 102                       101              94                169
# 103                       225              87                105
# 104                       137              41                 77
#
#      FIT O MIXED FRUIT 1L  FIT O MIXED FRUIT 200ML  FIT O ORANGE 1L  \
# 100                   105                      112              193
# 101                    70                      112              141
# 102                   100                      274              165
# 103                    83                      128              317
# 104                    54                       79              101
#
#      FIT O ORANGE 200ML  GINGER BEER 1.5L  GINGER BEER 1L  GINGER BEER 400ML  \
# 100                 112               673             234                 51
# 101                  76               568             194                 81
# 102                 106               893             273                 11
# 103                 129               669               0                 32
# 104                  66               544             210                 26
#
#      GINGER BEER 500ML  GINGER BEER SUGAR FREE 500ML  KIK COLA 1L  \
# 100                105                            69           28
# 101                126                           103           18
# 102                138                           107           27
# 103                228                           121           12
# 104                101                            42           28
#
#      LEMONADE 1.5L  LEMONADE 1L  LEMONADE 500ML  LIME CRUSH JUICE 1L  \
# 100            105           15              69                    0
# 101             73           12              29                    0
# 102            203           62              22                    0
# 103            210           34              84                    0
# 104             66           28              47                    0
#
#      NECTO 1.5L  NECTO 1L  NECTO 500ML  ORANGE BARLEY 1.5L  ORANGE CRUSH 1.5L  \
# 100         460        30           38                 235                145
# 101         330        14           34                 219                128
# 102         391        34           36                 435                106
# 103         215         0           46                 206                 88
# 104         149        25           41                 217                 26
#
#      ORANGE CRUSH 1L  ORANGE CRUSH 500ML  SODA 1L  SODA 500ML  SODA PET 1.5L  \
# 100               33                  73      235         275            320
# 101               21                  47      129         116            188
# 102               31                  67      120         229            411
# 103                0                  55      237         488            281
# 104               26                  36      373         376            358
#
#      STRAWBERRY MILK 180ML  TONIC PET 500ML  TWISTEE APPLE 1L
# 100                     72              305                15
# 101                     62              128                35
# 102                     76              213                38
# 103                     85              651                36
# 104                     55              280                30

# %%
df.shape
# Out:
# (124, 45)

# %%
train = df.iloc[:100].copy()
test = df.iloc[100:].copy()

# %%
train = train.drop(columns=['shop_id'])

# %%
test = test.drop(columns=['shop_id'])

# %%
train['shop_profile'] = train['shop_profile'].replace({'High':2, 'Moderate':1, 'Low':0})

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 44 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   shop_area_sq_ft               100 non-null    int64
#  1   shop_profile                  100 non-null    int64
#  2   quantity_sold                 100 non-null    int64
#  3   tot_sales_amount              100 non-null    int64
#  4   customer_id                   100 non-null    int64
#  5   invoice_id                    100 non-null    int64
#  6   transaction_date              100 non-null    int64
#  7   BOTTLED DRINKING WATER 1.5L   100 non-null    int64
#  8   BOTTLED DRINKING WATER 500ML  100 non-null    int64
#  9   CHOCOLATE MILK 180ML          100 non-null    int64
#  10  CREAM SODA 1.5L               100 non-null    int64
#  11  CREAM SODA 1L                 100 non-null    int64
#  12  CREAM SODA 500ML              100 non-null    int64
#  13  CREAM SODA APPLE POP 1L       100 non-null    int64
#  14  DRY GINGER ALE PET 500ML      100 non-null    int64
#  15  FIT O MANGO 1L                100 non-null    int64
#  16  FIT O MANGO 200ML             100 non-null    int64
#  17  FIT O MIXED FRUIT 1L          100 non-null    int64
#  18  FIT O MIXED FRUIT 200ML       100 non-null    int64
#  19  FIT O ORANGE 1L               100 non-null    int64
#  20  FIT O ORANGE 200ML            100 non-null    int64
#  21  GINGER BEER 1.5L              100 non-null    int64
#  22  GINGER BEER 1L                100 non-null    int64
#  23  GINGER BEER 400ML             100 non-null    int64
#  24  GINGER BEER 500ML             100 non-null    int64
#  25  GINGER BEER SUGAR FREE 500ML  100 non-null    int64
#  26  KIK COLA 1L                   100 non-null    int64
#  27  LEMONADE 1.5L                 100 non-null    int64
#  28  LEMONADE 1L                   100 non-null    int64
#  29  LEMONADE 500ML                100 non-null    int64
#  30  LIME CRUSH JUICE 1L           100 non-null    int64
#  31  NECTO 1.5L                    100 non-null    int64
#  32  NECTO 1L                      100 non-null    int64
#  33  NECTO 500ML                   100 non-null    int64
#  34  ORANGE BARLEY 1.5L            100 non-null    int64
#  35  ORANGE CRUSH 1.5L             100 non-null    int64
#  36  ORANGE CRUSH 1L               100 non-null    int64
#  37  ORANGE CRUSH 500ML            100 non-null    int64
#  38  SODA 1L                       100 non-null    int64
#  39  SODA 500ML                    100 non-null    int64
#  40  SODA PET 1.5L                 100 non-null    int64
#  41  STRAWBERRY MILK 180ML         100 non-null    int64
#  42  TONIC PET 500ML               100 non-null    int64
#  43  TWISTEE APPLE 1L              100 non-null    int64
# dtypes: int64(44)
# memory usage: 34.5 KB

# %%
# X = train.drop(columns=['shop_profile']).values
# Y = train['shop_profile'].values

# from sklearn.model_selection import train_test_split
# x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42, stratify=Y)

# %%
from sklearn.preprocessing import StandardScaler
# Initialize the StandardScaler object
scaler = StandardScaler()

# Scale the columns of the numpy array
train_scaled = scaler.fit_transform(train.drop(columns=['shop_profile']).values)
test_scaled = scaler.transform(test.drop(columns=['shop_profile']).values)

# %% [markdown]
# ## Cluster Analysis

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Import required libraries
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

sse = []

# Fit KMeans algorithm for different values of k
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(train_scaled)
    sse.append(kmeans.inertia_)

# Plot the SSE values against the number of clusters (k)
plt.figure(figsize=(4,3))
plt.plot(range(1, 11), sse)
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Sum of Squared Errors (SSE)")
plt.title("Elbow Method")
plt.show()

# %%
# Perform KMeans clustering with optimal number of clusters
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=300, n_init=10, random_state=0)
X = train_scaled
y_kmeans = kmeans.fit_predict(train_scaled)

# Visualize the clusters
plt.figure(figsize=(6,4))
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s=100, c='red', label='Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s=100, c='blue', label='Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s=100, c='green', label='Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s=100, c='purple', label='Cluster 4')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='yellow', label='Centroids')
plt.title('Clusters')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.show()

# %%
cluster_pred = pd.DataFrame()
cluster_pred['Actual'] = train.shop_profile
cluster_pred['KMeans_Pred'] = y_kmeans
cluster_pred.head()
# Out:
#    Actual  KMeans_Pred
# 0       1            1
# 1       2            2
# 2       0            2
# 3       0            2
# 4       0            1

# %%
cluster_pred.corr()
# Out:
#                Actual  KMeans_Pred
# Actual       1.000000    -0.547079
# KMeans_Pred -0.547079     1.000000

# %%
freq_table = pd.crosstab(cluster_pred['KMeans_Pred'], cluster_pred['Actual'])
freq_table
# Out:
# Actual        0   1   2
# KMeans_Pred
# 0             2   4  21
# 1             7  13   3
# 2            27  16   7

# %%
# cluster_pred['Actual'] = cluster_pred['Actual'].replace({2:'High', 1:'Moderate', 0:'Low'})
# cluster_pred["KMeans_Pred"] = cluster_pred["KMeans_Pred"].replace({3:'High', 1:'High', 2:'Moderate', 0:'Low'})

cluster_pred['Actual'] = cluster_pred['Actual'].replace({2:'High', 1:'Moderate', 0:'Low'})
cluster_pred["KMeans_Pred"] = cluster_pred["KMeans_Pred"].replace({0:'High', 1:'Moderate', 2:'Low'})

# %%
freq_table1 = pd.crosstab(cluster_pred['KMeans_Pred'], cluster_pred['Actual'])
freq_table1
# Out:
# Actual       High  Low  Moderate
# KMeans_Pred
# High           21    2         4
# Low             7   27        16
# Moderate        3    7        13

# %%
freq_table1 = pd.crosstab(cluster_pred['KMeans_Pred'], cluster_pred['Actual'])
freq_table1
# Out:
# Actual       High  Low  Moderate
# KMeans_Pred
# High           21    2         4
# Low             7   27        16
# Moderate        3    7        13

# %%
test_cluster_output = kmeans.predict(test_scaled)
test_cluster_output
# Out:
# array([2, 1, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 1, 0, 1, 2, 2, 2, 2, 1, 2, 2,
#        0, 1])

# %%
train['cluser_feature'] = y_kmeans
test['cluser_feature'] = test_cluster_output

# %%
train['cluser_feature'].value_counts()
# Out:
# 2    50
# 0    27
# 1    23
# Name: cluser_feature, dtype: int64

# %%
test['cluser_feature'].value_counts()
# Out:
# 2    16
# 1     6
# 0     2
# Name: cluser_feature, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

X = train.drop(columns=['shop_profile']).values
Y = train['shop_profile'].values

scaler = StandardScaler()

# Scale the columns of the numpy array
X = scaler.fit_transform(X)
test = scaler.transform(test.drop(columns=['shop_profile']).values)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42, stratify=Y)

# %%
# Initialize the StandardScaler object

# %%
# from catboost import CatBoostClassifier
# model = CatBoostClassifier(
#     task_type="GPU",
#     iterations=1000,
#     random_seed=0,
#     learning_rate=0.01
# )
# model.fit(
#     x_train, y_train,
# #     cat_features=cat_cols,
# #     eval_set=(X_val, y_val),
# #     logging_level='Silent'
# )
# print('Model is fitted: ' + str(model.is_fitted()))
# print('Model params:')
# print(model.get_params())

# %%
# pred = model.predict(x_test)

# %%
# prediction = pd.DataFrame()
# prediction['Actual'] = y_test
# prediction['Presicted'] = pred
# prediction

# %%
# from sklearn.metrics import f1_score

# f1_score(y_test, pred, average='micro')

# %%
# cols= train.drop(columns=['shop_profile']).columns

# %%
# pd.DataFrame({'names':cols, 'import':model.feature_importances_}).sort_values(by='import', ascending=False)

# %%
# y_test

# %%
# from MLmodels import MachineLearningModels
# MachineLearningModels.ml_model(x_train, y_train, x_test, y_test)

# %%
# from sklearn.linear_model import LogisticRegression
# from sklearn.naive_bayes import GaussianNB
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.svm import SVC
# from sklearn.linear_model import SGDClassifier
# from sklearn.linear_model import Perceptron
# from sklearn.linear_model import RidgeClassifier
# from sklearn.svm import SVC
# from sklearn.ensemble import RandomForestClassifier
# from lightgbm import LGBMClassifier
# from mlxtend.classifier import StackingClassifier
# import matplotlib.gridspec as gridspec
# from sklearn.tree import DecisionTreeClassifier

# import itertools
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
# import matplotlib.gridspec as gridspec

# from sklearn.model_selection import cross_val_score, train_test_split

# from mlxtend.plotting import plot_learning_curves
# from mlxtend.plotting import plot_decision_regions

# X, y = x_train, y_train

# clf1 = KNeighborsClassifier()
# clf2 = RandomForestClassifier(random_state=1)
# clf3 = LogisticRegression()
# clf4 = DecisionTreeClassifier()
# lr = LGBMClassifier()
# sclf = StackingClassifier(classifiers=[clf1, clf2, clf3], 
#                           meta_classifier=lr)

# %%
# label = ['KNN', 'Random Forest', 'LogisticRegression', 'Stacking Classifier']
# clf_list = [clf1, clf2, clf3, sclf]
    
# fig = plt.figure(figsize=(10,8))
# gs = gridspec.GridSpec(2, 2)
# grid = itertools.product([0,1],repeat=2)

# clf_cv_mean = []
# clf_cv_std = []
# for clf, label, grd in zip(clf_list, label, grid):
        
#     scores = cross_val_score(clf, X, y, cv=5, scoring='f1_micro')
#     print ("Accuracy: %.2f (+/- %.2f) [%s]" %(scores.mean(), scores.std(), label))
#     clf_cv_mean.append(scores.mean())
#     clf_cv_std.append(scores.std())
        
#     clf.fit(X, y)

# %%
# y_pred_final = sclf.predict(x_test)

# %%
# from sklearn.metrics import f1_score

# f1_score(y_test, y_pred_final, average='micro')

# %%
# from xgboost import XGBClassifier
# from lightgbm import LGBMClassifier
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.ensemble import RandomForestClassifier

# XGB = LGBMClassifier()
# XGB.fit(x_train, y_train)
# pred_xgb = XGB.predict(x_test)

# %%
# prediction = pd.DataFrame()
# prediction['Actual'] = y_test
# prediction['Presicted'] = pred_xgb
# prediction

# %%
# prediction.Presicted.value_counts()

# %%
# from sklearn.metrics import f1_score

# f1_score(y_test, pred_xgb, average='micro')

# %%
# import lightgbm as lgb
# from sklearn.model_selection import GridSearchCV
# from sklearn.metrics import roc_auc_score
# import pandas as pd
# import numpy as np


# # Create LightGBM dataset
# train_data = lgb.Dataset(x_train, label=y_train)

# # Define hyperparameters
# # Define hyperparameters
# params = {'objective': 'multiclass',
#           'num_classes': 3}

# # Create Grid Search object
# grid = GridSearchCV(estimator=lgb.LGBMClassifier(**params),
#                     param_grid={'learning_rate': [0.01, 0.05, 0.1],
#                                 'num_leaves': [15, 31, 63],
#                                 'max_depth': [3, 5, 7],
#                                 'min_child_samples': [10, 25, 50]},
#                     scoring='f1_micro',
#                     error_score='raise',
#                     n_jobs=-1,
#                     cv=5)

# # Fit the Grid Search object to the data
# grid.fit(x_train, y_train)

# # Print the best parameters and score
# print("Best parameters:", grid.best_params_)
# print("Best score:", grid.best_score_)

# # Predict the probabilities on the test set
# y_pred = grid.predict(x_test)

# f1_score(y_test, y_pred, average='micro')

# %%
from MLmodels import MachineLearningModels
MachineLearningModels.ml_model(x_train, y_train, x_test, y_test)
# Out:
# Logistic Regression:
#
# [0.4375 0.5625 0.5625 0.4375 0.4375]
# f1 score: 48.75 %
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82         7
#            1       1.00      0.29      0.44         7
#            2       0.75      1.00      0.86         6
#
#     accuracy                           0.75        20
#    macro avg       0.82      0.76      0.71        20
# weighted avg       0.82      0.75      0.70        20
#
#
# Confusion Matrix:
# [[7 0 0]
#  [3 2 2]
#  [0 0 6]]
# ---------------------------------------------------------------------------------------
# Gaussian Naive Bayes:
#
# [0.5625 0.5    0.5    0.625  0.5   ]
# f1 score: 53.75 %
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.86      0.67         7
#            1       0.00      0.00      0.00         7
#            2       0.62      0.83      0.71         6
#
#     accuracy                           0.55        20
#    macro avg       0.39      0.56      0.46        20
# weighted avg       0.38      0.55      0.45        20
#
#
# Confusion Matrix:
# [[6 0 1]
#  [5 0 2]
#  [0 1 5]]
# ---------------------------------------------------------------------------------------
# KNeighbors Classifier:
#
# [0.375  0.8125 0.5    0.5625 0.5   ]
# f1 score: 55.00 %
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.86      0.67         7
#            1       0.43      0.43      0.43         7
#            2       1.00      0.33      0.50         6
#
#     accuracy                           0.55        20
#    macro avg       0.66      0.54      0.53        20
# weighted avg       0.64      0.55      0.53        20
#
#
# Confusion Matrix:
# [[6 1 0]
#  [4 3 0]
#  [1 3 2]]
# ---------------------------------------------------------------------------------------
# SGD Classifier:
#
# [0.375  0.5    0.75   0.4375 0.4375]
# f1 score: 50.00 %
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.62      0.71      0.67         7
#            1       0.50      0.29      0.36         7
#            2       0.50      0.67      0.57         6
#
#     accuracy                           0.55        20
#    macro avg       0.54      0.56      0.53        20
# weighted avg       0.54      0.55      0.53        20
#
#
# Confusion Matrix:
# [[5 1 1]
#  [2 2 3]
#  [1 1 4]]
# ---------------------------------------------------------------------------------------
# Ridge Classifier:
#
# [0.375  0.5    0.625  0.375  0.1875]
# f1 score: 41.25 %
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.62      0.71      0.67         7
#            1       0.50      0.29      0.36         7
#            2       0.62      0.83      0.71         6
#
#     accuracy                           0.60        20
#    macro avg       0.58      0.61      0.58        20
# weighted avg       0.58      0.60      0.57        20
#
#
# Confusion Matrix:
# [[5 1 1]
#  [3 2 2]
#  [0 1 5]]
# ---------------------------------------------------------------------------------------
# Decision Tree Classifier:
#
# [0.625  0.5625 0.8125 0.5625 0.4375]
# f1 score: 60.00 %
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.86      0.80         7
#            1       0.60      0.43      0.50         7
#            2       0.43      0.50      0.46         6
#
#     accuracy                           0.60        20
#    macro avg       0.59      0.60      0.59        20
# weighted avg       0.60      0.60      0.59        20
#
#
# Confusion Matrix:
# [[6 1 0]
#  [0 3 4]
#  [2 1 3]]
# ---------------------------------------------------------------------------------------
# Random Forest Classifier:
#
# [0.3125 0.625  0.4375 0.5    0.4375]
# f1 score: 46.25 %
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.60      0.86      0.71         7
#            1       0.40      0.29      0.33         7
#            2       0.80      0.67      0.73         6
#
#     accuracy                           0.60        20
#    macro avg       0.60      0.60      0.59        20
# weighted avg       0.59      0.60      0.58        20
#
#
# Confusion Matrix:
# [[6 1 0]
#  [4 2 1]
#  [0 2 4]]
# ---------------------------------------------------------------------------------------
# Ada Boost Classifier:
#
# [0.4375 0.8125 0.4375 0.5625 0.375 ]
# f1 score: 52.50 %
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.71      0.59         7
#            1       0.25      0.14      0.18         7
#            2       0.50      0.50      0.50         6
#
#     accuracy                           0.45        20
#    macro avg       0.42      0.45      0.42        20
# weighted avg       0.41      0.45      0.42        20
#
#
# Confusion Matrix:
# [[5 2 0]
#  [3 1 3]
#  [2 1 3]]
# ---------------------------------------------------------------------------------------
# LightGBM Classifier :
#
# [0.5    0.75   0.6875 0.625  0.4375]
# f1 score: 60.00 %
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86         7
#            1       0.60      0.43      0.50         7
#            2       0.62      0.83      0.71         6
#
#     accuracy                           0.70        20
#    macro avg       0.69      0.71      0.69        20
# weighted avg       0.70      0.70      0.69        20
#
#
# Confusion Matrix:
# [[6 1 0]
#  [1 3 3]
#  [0 1 5]]
# ---------------------------------------------------------------------------------------
# XGBoost Classifier:
#
# [0.375  0.75   0.75   0.5    0.5625]
# f1 score: 58.75 %
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86         7
#            1       0.60      0.43      0.50         7
#            2       0.62      0.83      0.71         6
#
#     accuracy                           0.70        20
#    macro avg       0.69      0.71      0.69        20
# weighted avg       0.70      0.70      0.69        20
#
#
# Confusion Matrix:
# [[6 1 0]
#  [1 3 3]
#  [0 1 5]]
# ---------------------------------------------------------------------------------------

# %% [markdown]
# ### Finetune Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split


# Define a parameter grid
param_grid = {'C': [0.01, 0.1, 1, 10, 100],
              'penalty': ['l1', 'l2'],
              'solver': ['lbfgs', 'liblinear', 'saga']}

# Create a logistic regression model
logreg = LogisticRegression()

# Perform a grid search with cross-validation
grid_lr = GridSearchCV(logreg, param_grid, cv=5, scoring='f1_micro', n_jobs=-1)
grid_lr.fit(X, Y)

# Get the best hyperparameters and model
# best_params = grid_search.best_params_
# best_model = grid_search.best_estimator_
print("Best hyperparameters: ", grid_lr.best_params_)
print("Best score: ", grid_lr.best_score_)
# Out:
# Best hyperparameters:  {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}
# Best score:  0.62

# %%
# Get the best parameters
best_params = grid_lr.best_params_

# Create new LightGBM model with the best parameters
lr_model = LogisticRegression(**best_params)

# Train the model on the full training set
lr_model.fit(X, Y)

# Make predictions on the testing set
# lr_tuned_pred = lr_model.predict(test.drop(columns=['shop_profile']).values)
lr_tuned_pred = lr_model.predict(test)

# %% [markdown]
# ### Finetune XGBoost

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV


# Define the XGBoost model
model = xgb.XGBClassifier(objective='binary:logistic')

# Define the parameter grid for hyperparameter tuning
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.1, 0.01, 0.001],
    'n_estimators': [50, 100, 200, 250, 300],
    'subsample': [0.5, 0.8, 1.0]
}

# Perform grid search cross-validation to find the best hyperparameters
grid_xgb = GridSearchCV(estimator=model, param_grid=param_grid,
                           scoring='f1_micro',
                           error_score='raise',
                           n_jobs=-1,
                           cv=5)
grid_xgb.fit(X, Y)

# Print the best hyperparameters and the corresponding accuracy score
print("Best hyperparameters: ", grid_xgb.best_params_)
# print("scores : ", grid_xgb.cv_results_)
print("Best score: ", grid_xgb.best_score_)
# Out:
# Best hyperparameters:  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.5}
# Best score:  0.67

# %%
# Get the best parameters
best_params = grid_xgb.best_params_

# Create new LightGBM model with the best parameters
xgb_model = xgb.XGBClassifier(**best_params)

# Train the model on the full training set
xgb_model.fit(X, Y)

# Make predictions on the testing set
xgb_tuned_pred = xgb_model.predict(test)

# %% [markdown]
# ### Finetune LGBM

# %%
# 'max_depth': np.arange(5, 50),
#     'min_child_weight': np.arange(1, 10),
#     'learning_rate': np.logspace(-3, 0, num=1000),
#     'gamma': np.linspace(0, 1, num=1000),
#     'subsample': np.random.uniform(0.2, 1.0, size=1000),
#     'colsample_bytree': np.random.uniform(0.4, 1.0, size=1000),
#     'min_child_samples': np.random.randint(100, 500, size=1000),

# %%
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV
from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform

# Create LightGBM dataset
# train_data = lgb.Dataset(X, label=Y)

# Define hyperparameters
# Define hyperparameters
params = {'objective': 'multiclass',
          'num_classes': 3,
          'device': 'gpu'}

param_test = {'learning_rate': [0.01, 0.05, 0.1],
              'num_leaves': [15, 31, 63,],
              'max_depth': [3, 5, 7, 9],
              'min_child_samples': [10, 25, 50],
#               'reg_alpha': [1e-1, 1, 5, 7, 10, 100],
#               'reg_lambda': [1e-1, 1, 5, 10, 20, 100],
#               'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4]
             }

# param_test1 ={'num_leaves': sp_randint(6, 50), 
#              'min_child_samples': sp_randint(100, 500), 
#              'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4],
#              'subsample': sp_uniform(loc=0.2, scale=0.8), 
#              'colsample_bytree': sp_uniform(loc=0.4, scale=0.6),
#              'reg_alpha': [0, 1e-1, 1, 2, 5, 7, 10, 50, 100],
#              'reg_lambda': [0, 1e-1, 1, 5, 10, 20, 50, 100]}


# Create Grid Search object
grid = GridSearchCV(estimator=lgb.LGBMClassifier(**params),
                    param_grid=param_test,
                    scoring='f1_micro',
                    error_score='raise',
                    n_jobs=-1,
                    cv=5)

# Fit the Grid Search object to the data
grid.fit(X, Y)

# Print the best parameters and score
print("Best parameters:", grid.best_params_)
print("Best score:", grid.best_score_)

# Predict the probabilities on the test set
# y_pred = grid.predict(x_test)
# Out:
# Best parameters: {'learning_rate': 0.1, 'max_depth': 3, 'min_child_samples': 25, 'num_leaves': 15}
# Best score: 0.6900000000000001

# %%
# def learning_rate_010_decay_power_099(current_iter):
#     base_learning_rate = 0.1
#     lr = base_learning_rate  * np.power(.99, current_iter)
#     return lr if lr > 1e-3 else 1e-3

# def learning_rate_010_decay_power_0995(current_iter):
#     base_learning_rate = 0.1
#     lr = base_learning_rate  * np.power(.995, current_iter)
#     return lr if lr > 1e-3 else 1e-3

# def learning_rate_005_decay_power_099(current_iter):
#     base_learning_rate = 0.05
#     lr = base_learning_rate  * np.power(.99, current_iter)
#     return lr if lr > 1e-3 else 1e-3

# %%
# import lightgbm as lgb
# fit_params={"early_stopping_rounds":30, 
#             "eval_metric" : 'multi_logloss', 
#             "eval_set" : [(x_test, y_test)],
#             'eval_names': ['valid'],
#             #'callbacks': [lgb.reset_parameter(learning_rate=learning_rate_010_decay_power_099)],
#             'verbose': 1,
#             'categorical_feature': 'auto'}

# %%
# opt_parameters = {'colsample_bytree': 0.9234, 'min_child_samples': 399, 'min_child_weight': 0.1, 'num_leaves': 13, 'reg_alpha': 2, 'reg_lambda': 5, 'subsample': 0.855}

# %%
# # Get the best parameters
# best_params = grid.best_params_

# #Configure locally from hardcoded values
# clf_final = lgb.LGBMClassifier(**best_params)
# #set optimal parameters
# # clf_final.set_params(**opt_parameters)

# #Train the final model with learning rate decay
# clf_final.fit(x_train, y_train, **fit_params, callbacks=[lgb.reset_parameter(learning_rate=learning_rate_010_decay_power_0995)])

# %%
# #Train the final model with learning rate decay
# lgbm_tuned_pred = clf_final.predict(test.drop(columns=['shop_profile']).values)

# %%
# Get the best parameters
# best_params = grid.best_params_
# best_params = {'learning_rate': 0.05, 'max_depth': 3, 'min_child_samples': 25, 'num_leaves': 15}
best_params = {'learning_rate': 0.1, 'max_depth': 3, 'min_child_samples': 25, 'min_child_weight': 1e-05, 'num_leaves': 31, 'reg_alpha': 0.1, 'reg_lambda': 5}
# Create new LightGBM model with the best parameters
lgb_model = lgb.LGBMClassifier(**best_params)

# Train the model on the full training set
lgb_model.fit(X, Y)

# Make predictions on the testing set
lgbm_tuned_pred = lgb_model.predict(test)

# %%
# Print feature importance from the first best estimator model
best_model = grid.best_estimator_
feat_imp = pd.DataFrame({'feature': train.drop(columns=['shop_profile']).columns, 
              'importance': best_model.feature_importances_}).sort_values(by='importance', ascending=False).reset_index(drop=True)
feat_imp
# Out:
#                          feature  importance
# 0                    NECTO 500ML          58
# 1   BOTTLED DRINKING WATER 500ML          40
# 2          STRAWBERRY MILK 180ML          39
# 3                     NECTO 1.5L          38
# 4    BOTTLED DRINKING WATER 1.5L          35
# 5              ORANGE CRUSH 1.5L          34
# 6                 FIT O MANGO 1L          26
# 7                  LEMONADE 1.5L          26
# 8               CREAM SODA 500ML          25
# 9                ORANGE CRUSH 1L          24
# 10                GINGER BEER 1L          24
# 11               TONIC PET 500ML          24
# 12            ORANGE CRUSH 500ML          23
# 13      DRY GINGER ALE PET 500ML          22
# 14                       SODA 1L          22
# 15       FIT O MIXED FRUIT 200ML          21
# 16       CREAM SODA APPLE POP 1L          20
# 17             GINGER BEER 400ML          20
# 18                 SODA PET 1.5L          19
# 19               FIT O ORANGE 1L          18
# 20                   LEMONADE 1L          18
# 21               shop_area_sq_ft          17
# 22               CREAM SODA 1.5L          17
# 23                   customer_id          16
# 24            FIT O ORANGE 200ML          13
# 25          FIT O MIXED FRUIT 1L          12
# 26                    SODA 500ML           8
# 27                   KIK COLA 1L           7
# 28  GINGER BEER SUGAR FREE 500ML           3
# 29             GINGER BEER 500ML           2
# 30                cluser_feature           1
# 31              TWISTEE APPLE 1L           1
# 32                LEMONADE 500ML           1
# 33              tot_sales_amount           1
# 34             FIT O MANGO 200ML           1
# 35                    invoice_id           1
# 36              transaction_date           0
# 37                 quantity_sold           0
# 38          CHOCOLATE MILK 180ML           0
# 39                 CREAM SODA 1L           0
# 40                      NECTO 1L           0
# 41           LIME CRUSH JUICE 1L           0
# 42              GINGER BEER 1.5L           0
# 43            ORANGE BARLEY 1.5L           0

# %%
plt.figure(figsize=(6, 3))
plt.barh(feat_imp['feature'][:10], feat_imp['importance'][:10])
plt.xticks(rotation=90)
plt.gca().invert_yaxis()
plt.xlabel('Features')
plt.ylabel('Importance')
plt.title('Top 10 Features by Importance')
plt.show()

# %%
# features = feat_imp['feature']
# importances = feat_imp['importance']
# indices = np.argsort(importances)

# # customized number 
# num_features = 10 

# plt.figure(figsize=(10,10))
# plt.title('Feature Importances')

# # only plot the customized number of features
# plt.barh(range(num_features), importances[indices[-num_features:]], color='b', align='center')
# plt.yticks(range(num_features), [features[i] for i in indices[-num_features:]])
# plt.xlabel('Relative Importance')
# plt.show()

# %%
# features = feat_imp['feature']
# importances = feat_imp['importance']
# indices = np.argsort(importances)

# plt.title('Feature Importances')
# plt.barh(range(len(indices)), importances[indices], color='b', align='center')
# plt.yticks(range(len(indices)), [features[i] for i in indices])
# plt.xlabel('Relative Importance')
# plt.show()


# # import lightgbm as lgb
# # import matplotlib.pyplot as plt


# # # Plot feature importance
# # lgb.plot_importance(best_model, max_num_features=10, height=0.5, figsize=(10,5))
# # plt.show()

# %%
feat_imp[feat_imp['import'] > 10].names.values
# Out:
# array(['BOTTLED DRINKING WATER 500ML', 'STRAWBERRY MILK 180ML',
#        'NECTO 500ML', 'FIT O MIXED FRUIT 200ML',
#        'BOTTLED DRINKING WATER 1.5L', 'CREAM SODA 500ML',
#        'ORANGE CRUSH 1.5L', 'FIT O MANGO 1L', 'CREAM SODA APPLE POP 1L',
#        '41', 'NECTO 1.5L', 'GINGER BEER 1L', 'SODA PET 1.5L',
#        'GINGER BEER 400ML', 'TONIC PET 500ML', 'customer_id',
#        'LEMONADE 1.5L'], dtype=object)

# %%
# feat_to_be_droped = feat_imp[feat_imp['import'] > 0].names.values

# %%
# X = train.drop(columns=['shop_profile'])
# X_2 = train.drop(columns=feat_to_be_droped)
# Y = train['shop_profile'].values

# import lightgbm as lgb
# from sklearn.model_selection import GridSearchCV

# # Create LightGBM dataset
# train_data = lgb.Dataset(X_2, label=Y)

# # Define hyperparameters
# # Define hyperparameters
# params = {'objective': 'multiclass',
#           'num_classes': 3}

# # Create Grid Search object
# grid = GridSearchCV(estimator=lgb.LGBMClassifier(**params),
#                     param_grid={'learning_rate': [0.01, 0.05, 0.1],
#                                 'num_leaves': [15, 31, 63, 90, 120],
#                                 'max_depth': [3, 5, 7, 9, 12],
#                                 'min_child_samples': [10, 25, 50]},
#                     scoring='f1_micro',
#                     error_score='raise',
#                     n_jobs=-1,
#                     cv=5)

# # Fit the Grid Search object to the data
# grid.fit(x_train, y_train)

# # Print the best parameters and score
# print("Best parameters:", grid.best_params_)
# print("Best score:", grid.best_score_)

# # Predict the probabilities on the test set
# y_pred = grid.predict(x_test)
# Out:
# Best parameters: {'learning_rate': 0.1, 'max_depth': 3, 'min_child_samples': 25, 'num_leaves': 15}
# Best score: 0.6125

# %%
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# XGB = XGBClassifier()
XGB = DecisionTreeClassifier()
XGB.fit(X, Y)
pred_test_xgb = XGB.predict(test.drop(columns=['shop_profile']).values)

# %%
pred_test_xgb
# Out:
# array([2, 0, 0, 0, 1, 0, 0, 2, 0, 0, 0, 0, 0, 1, 0, 2, 0, 2, 2, 1, 1, 1,
#        2, 1], dtype=int64)

# %%
pred_test_xgb
# Out:
# array([2, 0, 0, 0, 1, 0, 0, 2, 0, 0, 0, 0, 0, 1, 0, 2, 0, 2, 2, 1, 1, 1,
#        2, 1], dtype=int64)

# %%
df_test = pd.read_csv('Testing-data.csv')

# %%
df_test.shop_profile = lr_tuned_pred # lgbm_tuned_pred # lr_tuned_pred # xgb_tuned_pred
df_test.shop_profile = df_test.shop_profile.replace({2:'High', 1:'Moderate', 0:'Low'})

# %%
df_test
# Out:
#     shop_id shop_profile
# 0   SHOP046          Low
# 1   SHOP024          Low
# 2   SHOP023          Low
# 3   SHOP097     Moderate
# 4   SHOP044     Moderate
# 5   SHOP030          Low
# 6   SHOP038          Low
# 7   SHOP029     Moderate
# 8   SHOP096          Low
# 9   SHOP092     Moderate
# 10  SHOP081     Moderate
# 11  SHOP076          Low
# 12  SHOP080          Low
# 13  SHOP074         High
# 14  SHOP107     Moderate
# 15  SHOP108     Moderate
# 16  SHOP019          Low
# 17  SHOP002          Low
# 18  SHOP114         High
# 19  SHOP087          Low
# 20  SHOP050          Low
# 21  SHOP061          Low
# 22  SHOP056         High
# 23  SHOP070          Low

# %%
df_test.shop_profile.value_counts()
# Out:
# Low         14
# Moderate     7
# High         3
# Name: shop_profile, dtype: int64

# %%
df_test.dtypes
# Out:
# shop_id         object
# shop_profile    object
# dtype: object

# %%
csv = 'submission8.csv'
df_test.to_csv(csv, index=False)

# %%
sub = pd.read_csv(csv)
sub.head()
# Out:
#    shop_id shop_profile
# 0  SHOP046          Low
# 1  SHOP024          Low
# 2  SHOP023          Low
# 3  SHOP097     Moderate
# 4  SHOP044     Moderate

# %% [markdown]
# ## Analyse with previous dataframe

# %%
s = pd.read_csv('submission.csv')
s1 = pd.read_csv('submission1.csv')
s3 = pd.read_csv('submission3_lgbm_hp_tuned.csv')
s4 = pd.read_csv('submission4.csv')
s5 = pd.read_csv('submission5_test.csv')
s6 = pd.read_csv('submission3_lgbm_hp_tuned_manually_changed.csv')
s7 = pd.read_csv('submission7.csv')
s8 = pd.read_csv('submission8.csv')

# %%
s['submission1_62'] = s1['shop_profile']
s['submission3_66'] = s3['shop_profile']
s['submission4_58'] = s4['shop_profile']
s['submission5_62'] = s5['shop_profile']
s['submission6_66'] = s6['shop_profile']
s['submission7_62'] = s7['shop_profile']
s['submission_new'] = s8['shop_profile']
# s['submission_lr'] = lr_tuned_pred
# s['submission_lr'] = s['submission_lr'].replace({2:'High', 1:'Moderate', 0:'Low'})

# %%
s
# Out:
#     shop_id shop_profile submission1_62 submission3_66 submission4_58  \
# 0   SHOP046         High           High           High           High
# 1   SHOP024          Low            Low            Low            Low
# 2   SHOP023          Low            Low            Low            Low
# 3   SHOP097     Moderate       Moderate       Moderate       Moderate
# 4   SHOP044         High       Moderate       Moderate           High
# 5   SHOP030          Low           High            Low            Low
# 6   SHOP038     Moderate       Moderate       Moderate           High
# 7   SHOP029         High       Moderate       Moderate       Moderate
# 8   SHOP096          Low            Low            Low            Low
# 9   SHOP092          Low       Moderate       Moderate            Low
# 10  SHOP081     Moderate       Moderate       Moderate       Moderate
# 11  SHOP076          Low            Low            Low            Low
# 12  SHOP080          Low            Low            Low            Low
# 13  SHOP074          Low            Low            Low            Low
# 14  SHOP107     Moderate       Moderate       Moderate       Moderate
# 15  SHOP108          Low            Low            Low            Low
# 16  SHOP019          Low            Low            Low            Low
# 17  SHOP002         High           High           High           High
# 18  SHOP114         High           High           High           High
# 19  SHOP087     Moderate       Moderate       Moderate       Moderate
# 20  SHOP050          Low            Low            Low            Low
# 21  SHOP061          Low            Low            Low            Low
# 22  SHOP056         High           High           High           High
# 23  SHOP070     Moderate            Low            Low            Low
#
#    submission5_62 submission6_66 submission7_62 submission_new
# 0            High           High           High            Low
# 1             Low            Low            Low            Low
# 2             Low            Low            Low            Low
# 3        Moderate       Moderate       Moderate       Moderate
# 4        Moderate       Moderate       Moderate       Moderate
# 5             Low            Low            Low            Low
# 6        Moderate       Moderate       Moderate            Low
# 7        Moderate           High       Moderate       Moderate
# 8             Low            Low            Low            Low
# 9        Moderate            Low            Low       Moderate
# 10       Moderate       Moderate       Moderate       Moderate
# 11            Low            Low            Low            Low
# 12            Low            Low            Low            Low
# 13            Low            Low            Low           High
# 14       Moderate       Moderate       Moderate       Moderate
# 15            Low            Low            Low       Moderate
# 16            Low            Low            Low            Low
# 17           High           High           High            Low
# 18           High           High           High           High
# 19       Moderate       Moderate       Moderate            Low
# 20            Low            Low            Low            Low
# 21            Low            Low            Low            Low
# 22           High           High           High           High
# 23       Moderate            Low            Low            Low

# %%
def style_specific_cell(x):

    color = 'background-color: lightgreen'
    df1 = pd.DataFrame('', index=x.index, columns=x.columns)
    df1.iloc[5, 2] = color
    
    color = 'background-color: lightblue'
    df1.iloc[[4,7,9], 1] = color
    
    color = 'background-color: lightyellow'
    df1.iloc[[4,6,9], 4] = color
    
    color = 'background-color: lightgreen'
    df1.iloc[23, 5] = color
    
    color = 'background-color: orange'
    df1.iloc[[7, 9], 6] = color
    
    color = 'background-color: lightgreen'
    df1.iloc[23, 5] = color
    
    color = 'background-color: lightgreen'
    df1.iloc[23, 5] = color
    
    return df1

s.style.apply(style_specific_cell, axis=None)
# Out:
# <style type="text/css">
# #T_f3d93_row4_col1, #T_f3d93_row7_col1, #T_f3d93_row9_col1 {
#   background-color: lightblue;
# }
# #T_f3d93_row4_col4, #T_f3d93_row6_col4, #T_f3d93_row9_col4 {
#   background-color: lightyellow;
# }
# #T_f3d93_row5_col2, #T_f3d93_row23_col5 {
#   background-color: lightgreen;
# }
# #T_f3d93_row7_col6, #T_f3d93_row9_col6 {
#   background-color: orange;
# }
# </style>
# <table id="T_f3d93">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3d93_level0_col0" class="col_heading level0 col0" >shop_id</th>
#       <th id="T_f3d93_level0_col1" class="col_heading level0 col1" >shop_profile</th>
#       <th id="T_f3d93_level0_col2" class="col_heading level0 col2" >submission1_62</th>
#       <th id="T_f3d93_level0_col3" class="col_heading level0 col3" >submission3_66</th>
#       <th id="T_f3d93_level0_col4" class="col_heading level0 col4" >submission4_58</th>
#       <th id="T_f3d93_level0_col5" class="col_heading level0 col5" >submission5_62</th>
#       <th id="T_f3d93_level0_col6" class="col_heading level0 col6" >submission6_66</th>
#       <th id="T_f3d93_level0_col7" class="col_heading level0 col7" >submission7_62</th>
#       <th id="T_f3d93_level0_col8" class="col_heading level0 col8" >submission_new</th>
#       <th id="T_f3d93_level0_col9" class="col_heading level0 col9" >updated</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3d93_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f3d93_row0_col0" class="data row0 col0" >SHOP046</td>
#       <td id="T_f3d93_row0_col1" class="data row0 col1" >High</td>
#       <td id="T_f3d93_row0_col2" class="data row0 col2" >High</td>
#       <td id="T_f3d93_row0_col3" class="data row0 col3" >High</td>
#       <td id="T_f3d93_row0_col4" class="data row0 col4" >High</td>
#       <td id="T_f3d93_row0_col5" class="data row0 col5" >High</td>
#       <td id="T_f3d93_row0_col6" class="data row0 col6" >High</td>
#       <td id="T_f3d93_row0_col7" class="data row0 col7" >High</td>
#       <td id="T_f3d93_row0_col8" class="data row0 col8" >Low</td>
#       <td id="T_f3d93_row0_col9" class="data row0 col9" >High</td>
#     </tr>
#     <tr>
#       <th id="T_f3d93_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f3d93_row1_col0" class="data row1 col0" >SHOP024</td>
#       <td id="T_f3d93_row1_col1" class="data row1 col1" >Low</td>
#       <td id="T_f3d93_row1_col2" class="data row1 col2" >Low</td>
#       <td id="T_f3d93_row1_col3" class="data row1 col3" >Low</td>
#       <td id="T_f3d93_row1_col4" class="data row1 col4" >Low</td>
#       <td id="T_f3d93_row1_col5" class="data row1 col5" >Low</td>
#       <td id="T_f3d93_row1_col6" class="data row1 col6" >Low</td>
#       <td id="T_f3d93_row1_col7" class="data row1 col7" >Low</td>
#       <td id="T_f3d93_row1_col8" class="data row1 col8" >Low</td>
#       <td id="T_f3d93_row1_col9" class="data row1 col9" >Low</td>
#     </tr>
#     <tr>
#       <th id="T_f3d93_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f3d93_row2_col0" class="data row2 col0" >SHOP023</td>
#       <td id="T_f3d93_row2_col1" class="data row2 col1" >Low</td>
#       <td id="T_f3d93_row2_col2" class="data row2 col2" >Low</td>
#       <td id="T_f3d93_row2_col3" class="data row2 col3" >Low</td>
#       <td id="T_f3d93_row2_col4" class="data row2 col4" >Low</td>
#       <td id="T_f3d93_row2_col5" class="data row2 col5" >Low</td>
#       <td id="T_f3d93_row2_col6" class="data row2 col6" >Low</td>
#       <td id="T_f3d93_row2_col7" class="data row2 col7" >Low</td>
#       <td id="T_f3d93_row2_col8" class="data row2 col8" >Low</td>
#       <td id="T_f3d93_row2_col9" class="data row2 col9" >Low</td>
#     </tr>
#     <tr>
#       <th id="T_f3d93_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f3d93_row3_col0" class="data row3 col0" >SHOP097</td>
#       <td id="T_f3d93_row3_col1" class="data row3 col1" >Moderate</td>
#       <td id="T_f3d93_row3_col2" class="data row3 col2" >Moderate</td>
#       <td id="T_f3d93_row3_col3" class="data row3 col3" >Moderate</td>
#       <td id="T_f3d93_row3_col4" class="data row3 col4" >Moderate</td>
#       <td id="T_f3d93_row3_col5" class="data row3 col5" >Moderate</td>
#       <td id="T_f3d93_row3_col6" class="data row3 col6" >Moderate</td>
#       <td id="T_f3d93_row3_col7" class="data row3 col7" >Moderate</td>
#       <td id="T_f3d93_row3_col8" class="data row3 col8" >Moderate</td>
#       <td id="T_f3d93_row3_col9" class="data row3 col9" >Moderate</td>
#     </tr>
#     <tr>
#       <th id="T_f3d93_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f3d93_row4_col0" class="data row4 col0" >SHOP044</td>
#       <td id="T_f3d93_row4_col1" class="data row4 col1" >High</td>
#       <td id="T_f3d93_row4_col2" class="data row4 col2" >Moderate</td>
#       <td id="T_f3d93_row4_col3" class="data row4 col3" >Moderate</td>
#       <td id="T_f3d93_row4_col4" class="data row4 col4" >High</td>
#       <td id="T_f3d93_row4_col5" class="data row4 col5" >Moderate</td>
#       <td id="T_f3d93_row4_col6" class="data row4 col6" >Moderate</td>
#       <td id="T_f3d93_row4_col7" class="data row4 col7" >Moderate</td>
#       <td id="T_f3d93_row4_col8" class="data row4 col8" >Moderate</td>
#       <td id="T_f3d93_row4_col9" class="data row4 col9" >Moderate</td>
#     </tr>
#     <tr>
#       <th id="T_f3d93_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f3d93_row5_col0" class="data row5 col0" >SHOP030</td>
#       <td id="T_f3d93_row5_col1" class="data row5 col1" >Low</td>
#       <td id="T_f3d93_row5_col2" class="data row5 col2" >High</td>
#       <td id="T_f3d93_row5_col3" class="data row5 col3" >Low</td>
#       <td id="T_f3d93_row5_col4" class="data row5 col4" >Low</td>
#       <td id="T_f3d93_row5_col5" class="data row5 col5" >Low</td>
#       <td id="T_f3d93_row5_col6" class="data row5 col6" >Low</td>
#       <td id="T_f3d93_row5_col7" class="data row5 col7" >Low</td>
#       <td id="T_f3d93_row5_col8" class="data row5 col8" >Low</td>
#       <td id="T_f3d93_row5_col9" class="data row5 col9" >Low</td>
#     </tr>
#     <tr>
#       <th id="T_f3d93_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f3d93_row6_col0" class="data row6 col0" >SHOP038</td>
#       <td id="T_f3d93_row6_col1" class="data row6 col1" >Moderate</td>
#       <td id="T_f3d93_row6_col2" class="data row6 col2" >Moderate</td>
#       <td id="T_f3d93_row6_col3" class="data row6 col3" >Moderate</td>
#       <td id="T_f3d93_row6_col4" class="data row6 col4" >High</td>
#       <td id="T_f3d93_row6_col5" class="data row6 col5" >Moderate</td>
#       <td id="T_f3d93_row6_col6" class="data row6 col6" >Moderate</td>
#       <td id="T_f3d93_row6_col7" class="data row6 col7" >Moderate</td>
#       <td id="T_f3d93_row6_col8" class="data row6 col8" >Low</td>
#       <td id="T_f3d93_row6_col9" class="data row6 col9" >Low</td>
#     </tr>
#     <tr>
#       <th id="T_f3d93_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f3d93_row7_col0" class="data row7 col0" >SHOP029</td>
#       <td id="T_f3d93_row7_col1" class="data row7 col1" >High</td>
#       <td id="T_f3d93_row7_col2" class="data row7 col2" >Moderate</td>
#       <td id="T_f3d93_row7_col3" class="data row7 col3" >Moderate</td>
#       <td id="T_f3d93_row7_col4" class="data row7 col4" >Moderate</td>
#       <td id="T_f3d93_row7_col5" class="data row7 col5" >Moderate</td>
#       <td id="T_f3d93_row7_col6" class="data row7 col6" >High</td>
#       <td id="T_f3d93_row7_col7" class="data row7 col7" >Moderate</td>
#       <td id="T_f3d93_row7_col8" class="data row7 col8" >Moderate</td>
#       <td id="T_f3d93_row7_col9" class="data row7 col9" >High</td>
#     </tr>
#     <tr>
#       <th id="T_f3d93_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f3d93_row8_col0" class="data row8 col0" >SHOP096</td>
#       <td id="T_f3d93_row8_col1" class="data row8 col1" >Low</td>
#       <td id="T_f3d93_row8_col2" class="data row8 col2" >Low</td>
#       <td id="T_f3d93_row8_col3" class="data row8 col3" >Low</td>
#       <td id="T_f3d93_row8_col4" class="data row8 col4" >Low</td>
#       <td id="

# %%
s8.dtypes
# Out:
# shop_id         object
# shop_profile    object
# dtype: object

# %%
s8.to_csv('last_sub.csv', index=False)

# %%
s8['shop_profile'].value_counts()
# Out:
# Low         13
# Moderate     6
# High         5
# Name: shop_profile, dtype: int64

# %%
s['updated'] = s8['shop_profile']
s
# Out:
#     shop_id shop_profile submission1_62 submission3_66 submission4_58  \
# 0   SHOP046         High           High           High           High
# 1   SHOP024          Low            Low            Low            Low
# 2   SHOP023          Low            Low            Low            Low
# 3   SHOP097     Moderate       Moderate       Moderate       Moderate
# 4   SHOP044         High       Moderate       Moderate           High
# 5   SHOP030          Low           High            Low            Low
# 6   SHOP038     Moderate       Moderate       Moderate           High
# 7   SHOP029         High       Moderate       Moderate       Moderate
# 8   SHOP096          Low            Low            Low            Low
# 9   SHOP092          Low       Moderate       Moderate            Low
# 10  SHOP081     Moderate       Moderate       Moderate       Moderate
# 11  SHOP076          Low            Low            Low            Low
# 12  SHOP080          Low            Low            Low            Low
# 13  SHOP074          Low            Low            Low            Low
# 14  SHOP107     Moderate       Moderate       Moderate       Moderate
# 15  SHOP108          Low            Low            Low            Low
# 16  SHOP019          Low            Low            Low            Low
# 17  SHOP002         High           High           High           High
# 18  SHOP114         High           High           High           High
# 19  SHOP087     Moderate       Moderate       Moderate       Moderate
# 20  SHOP050          Low            Low            Low            Low
# 21  SHOP061          Low            Low            Low            Low
# 22  SHOP056         High           High           High           High
# 23  SHOP070     Moderate            Low            Low            Low
#
#    submission5_62 submission6_66 submission7_62 submission_new   updated
# 0            High           High           High            Low      High
# 1             Low            Low            Low            Low       Low
# 2             Low            Low            Low            Low       Low
# 3        Moderate       Moderate       Moderate       Moderate  Moderate
# 4        Moderate       Moderate       Moderate       Moderate  Moderate
# 5             Low            Low            Low            Low       Low
# 6        Moderate       Moderate       Moderate            Low       Low
# 7        Moderate           High       Moderate       Moderate      High
# 8             Low            Low            Low            Low       Low
# 9        Moderate            Low            Low       Moderate  Moderate
# 10       Moderate       Moderate       Moderate       Moderate  Moderate
# 11            Low            Low            Low            Low       Low
# 12            Low            Low            Low            Low       Low
# 13            Low            Low            Low           High       Low
# 14       Moderate       Moderate       Moderate       Moderate  Moderate
# 15            Low            Low            Low       Moderate  Moderate
# 16            Low            Low            Low            Low       Low
# 17           High           High           High            Low      High
# 18           High           High           High           High      High
# 19       Moderate       Moderate       Moderate            Low       Low
# 20            Low            Low            Low            Low       Low
# 21            Low            Low            Low            Low       Low
# 22           High           High           High           High      High
# 23       Moderate            Low            Low            Low       Low

# %%
s8.iloc[17,1] = 'High'

# %%
s8.iloc[13,1] = 'Low'

# %%
s8.iloc[0,1] = 'High'

# %%
s8.iloc[7,1] = 'High'

# %%
# ss = pd.DataFrame(lgb_model.predict_proba(test.drop(columns=['shop_profile']).values), columns=['Low','Moderate','High'])
ss = pd.DataFrame(lgb_model.predict_proba(test), columns=['Low','Moderate','High'])
ss['Output'] = s3['shop_profile']
ss
# Out:
#          Low  Moderate      High    Output
# 0   0.178036  0.067661  0.754303      High
# 1   0.684408  0.142986  0.172606       Low
# 2   0.752369  0.166314  0.081317       Low
# 3   0.074608  0.877234  0.048157  Moderate
# 4   0.168148  0.488127  0.343724  Moderate
# 5   0.617077  0.139230  0.243693       Low
# 6   0.316289  0.465460  0.218252  Moderate
# 7   0.176674  0.585995  0.237331  Moderate
# 8   0.779014  0.207483  0.013504       Low
# 9   0.554719  0.435044  0.010237  Moderate
# 10  0.058859  0.768909  0.172233  Moderate
# 11  0.905105  0.065789  0.029106       Low
# 12  0.918844  0.050244  0.030911       Low
# 13  0.754229  0.140021  0.105750       Low
# 14  0.161225  0.692021  0.146754  Moderate
# 15  0.871947  0.046416  0.081637       Low
# 16  0.738758  0.202549  0.058693       Low
# 17  0.227097  0.024325  0.748578      High
# 18  0.244336  0.153490  0.602173      High
# 19  0.248648  0.694575  0.056777  Moderate
# 20  0.843670  0.077867  0.078464       Low
# 21  0.742855  0.226652  0.030493       Low
# 22  0.054398  0.227892  0.717710      High
# 23  0.657328  0.335562  0.007110       Low

# %%
modify_66 = s3.copy()
modify_66.iloc[7, 1] = 'High'
modify_66.iloc[9, 1] = 'Low'
s3['modify'] = modify_66.iloc[:,1]
s3
# Out:
#     shop_id shop_profile    modify
# 0   SHOP046         High      High
# 1   SHOP024          Low       Low
# 2   SHOP023          Low       Low
# 3   SHOP097     Moderate  Moderate
# 4   SHOP044     Moderate  Moderate
# 5   SHOP030          Low       Low
# 6   SHOP038     Moderate  Moderate
# 7   SHOP029     Moderate      High
# 8   SHOP096          Low       Low
# 9   SHOP092     Moderate       Low
# 10  SHOP081     Moderate  Moderate
# 11  SHOP076          Low       Low
# 12  SHOP080          Low       Low
# 13  SHOP074          Low       Low
# 14  SHOP107     Moderate  Moderate
# 15  SHOP108          Low       Low
# 16  SHOP019          Low       Low
# 17  SHOP002         High      High
# 18  SHOP114         High      High
# 19  SHOP087     Moderate  Moderate
# 20  SHOP050          Low       Low
# 21  SHOP061          Low       Low
# 22  SHOP056         High      High
# 23  SHOP070          Low       Low

# %%
modify_66.to_csv('submission3_lgbm_hp_tuned_manually_changed.csv', index=False)

# %%
s3.modify.value_counts()
# Out:
# Low         13
# Moderate     6
# High         5
# Name: modify, dtype: int64

# %%
def style_specific_cell(x):
    print(x)
    if col.name == 'submission1_62':
        color = 'background-color: lightgreen'
        df1 = pd.DataFrame('', index=x.index, columns=x.columns)
        df1.iloc[2, 5] = color
    if col.name == 'submission4_58':
        color = 'background-color: lightgreen'
        df1 = pd.DataFrame('', index=x.index, columns=x.columns)
        df1.iloc[2, [4,6,9]] = color
    if col.name == 'b':
        color = 'background-color: lightgreen'
        df1 = pd.DataFrame('', index=x.index, columns=x.columns)
        df1.iloc[2, 8] = color
    if col.name == 'b':
        color = 'background-color: lightgreen'
        df1 = pd.DataFrame('', index=x.index, columns=x.columns)
        df1.iloc[2, 8] = color   
    
    return df1

s_col = s.style.apply(style_specific_cell, axis=0)
s_col
# Out:
# 0     SHOP046
# 1     SHOP024
# 2     SHOP023
# 3     SHOP097
# 4     SHOP044
# 5     SHOP030
# 6     SHOP038
# 7     SHOP029
# 8     SHOP096
# 9     SHOP092
# 10    SHOP081
# 11    SHOP076
# 12    SHOP080
# 13    SHOP074
# 14    SHOP107
# 15    SHOP108
# 16    SHOP019
# 17    SHOP002
# 18    SHOP114
# 19    SHOP087
# 20    SHOP050
# 21    SHOP061
# 22    SHOP056
# 23    SHOP070
# Name: shop_id, dtype: object
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~\anaconda3\envs\tf\lib\site-packages\IPython\core\formatters.py:342, in BaseFormatter.__call__(self, obj)
#     340     method = get_real_method(obj, self.print_method)
#     341     if method is not None:
# --> 342         return method()
#     343     return None
#     344 else:
#
# File ~\anaconda3\envs\tf\lib\site-packages\pandas\io\formats\style.py:385, in Styler._repr_html_(self)
#     380 """
#     381 Hooks into Jupyter notebook rich display system, which calls _repr_html_ by
#     382 default if an object is returned at the end of a cell.
#     383 """
#     384 if get_option("styler.render.repr") == "html":
# --> 385     return self.to_html()
#     386 return None
#
# File ~\anaconda3\envs\tf\lib\site-packages\pandas\io\formats\style.py:1377, in Styler.to_html(self, buf, table_uuid, table_attributes, sparse_index, sparse_columns, bold_headers, caption, max_rows, max_columns, encoding, doctype_html, exclude_styles, **kwargs)
#    1374     obj.set_caption(caption)
#    1376 # Build HTML string..
# -> 1377 html = obj._render_html(
#    1378     sparse_index=sparse_index,
#    1379     sparse_columns=sparse_columns,
#    1380     max_rows=max_rows,
#    1381     max_cols=max_columns,
#    1382     exclude_styles=exclude_styles,
#    1383     encoding=encoding or get_option("styler.render.encoding"),
#    1384     doctype_html=doctype_html,
#    1385     **kwargs,
#    1386 )
#    1388 return save_to_buffer(
#    1389     html, buf=buf, encoding=(encoding if buf is not None else None)
#    1390 )
#
# File ~\anaconda3\envs\tf\lib\site-packages\pandas\io\formats\style_render.py:206, in StylerRenderer._render_html(self, sparse_index, sparse_columns, max_rows, max_cols, **kwargs)
#     194 def _render_html(
#     195     self,
#     196     sparse_index: bool,
#    (...)
#     200     **kwargs,
#     201 ) -> str:
#     202     """
#     203     Renders the ``Styler`` including all applied styles to HTML.
#     204     Generates a dict with necessary kwargs passed to jinja2 template.
#     205     """
# --> 206     d = self._render(sparse_index, sparse_columns, max_rows, max_cols, "&nbsp;")
#     207     d.update(kwargs)
#     208     return self.template_html.render(
#     209         **d,
#     210         html_table_tpl=self.template_html_table,
#     211         html_style_tpl=self.template_html_style,
#     212     )
#
# File ~\anaconda3\envs\tf\lib\site-packages\pandas\io\formats\style_render.py:163, in StylerRenderer._render(self, sparse_index, sparse_columns, max_rows, max_cols, blank)
#     149 def _render(
#     150     self,
#     151     sparse_index: bool,
#    (...)
#     155     blank: str = "",
#     156 ):
#     157     """
#     158     Computes and applies styles and then generates the general render dicts.
#     159
#     160     Also extends the `ctx` and `ctx_index` attributes with those of concatenated
#     161     stylers for use within `_translate_latex`
#     162     """
# --> 163     self._compute()
#     164     dxs = []
#     165     ctx_len = len(self.index)
#
# File ~\anaconda3\envs\tf\lib\site-packages\pandas\io\formats\style_render.py:258, in StylerRenderer._compute(self)
#     256 r = self
#     257 for func, args, kwargs in self._todo:
# --> 258     r = func(self)(*args, **kwargs)
#     259 return r
#
# File ~\anaconda3\envs\tf\lib\site-packages\pandas\io\formats\style.py:1736, in Styler._apply(self, func, axis, subset, **kwargs)
#    1734 axis = self.data._get_axis_number(axis)
#    1735 if axis == 0:
# -> 1736     result = data.apply(func, axis=0, **kwargs)
#    1737 else:
#    1738     result = data.T.apply(func, axis=0, **kwargs).T  # see GH 42005
#
# File ~\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\envs\tf\lib\site-packages\pandas\core\apply.py:764, in FrameApply.apply(self)
#     761 elif self.raw:
#     762     return self.apply_raw()
# --> 764 return self.apply_standard()
#
# File ~\anaconda3\envs\tf\lib\site-packages\pandas\core\apply.py:891, in FrameApply.apply_standard(self)
#     890 def apply_standard(self):
# --> 891     results, res_index = self.apply_series_generator()
#     893     # wrap results
#     894     return self.wrap_results(results, res_index)
#
# File ~\anaconda3\envs\tf\lib\site-packages\pandas\core\apply.py:907, in FrameApply.apply_series_generator(self)
#     904 with option_context("mode.chained_assignment", None):
#     905     for i, v in enumerate(series_gen):
#     906         # ignore SettingWithCopy here in case the user mutates
# --> 907         results[i] = self.f(v)
#     908         if isinstance(results[i], ABCSeries):
#     909             # If we have a view on v, we need to make a copy because
#     910             #  series_generator will swap out the underlying data
#     911             results[i] = results[i].copy(deep=False)
#
# Cell In[76], line 3, in style_specific_cell(x)
#       1 def style_specific_cell(x):
#       2     print(x)
# ----> 3     if col.name == 'submission1_62':
#       4         color = 'background-color: lightgreen'
#       5         df1 = pd.DataFrame('', index=x.index, columns=x.columns)
#
# NameError: name 'col' is not defined

# %%
# Define a function to highlight specific rows
def highlight_rows(x):
    if x.name in [4, 6]:
        return ['background: lightgreen'] * len(x)
    elif x.name in [9, 7, 23, 21]:
        return ['background: yellow'] * len(x)
    else:
        return [''] * len(x)

# Apply the function to the dataframe and display it
s_col = s.style.apply(highlight_rows, axis=1)
s_col
# Out:
# <style type="text/css">
# #T_e8bd2_row4_col0, #T_e8bd2_row4_col1, #T_e8bd2_row4_col2, #T_e8bd2_row4_col3, #T_e8bd2_row4_col4, #T_e8bd2_row4_col5, #T_e8bd2_row4_col6, #T_e8bd2_row6_col0, #T_e8bd2_row6_col1, #T_e8bd2_row6_col2, #T_e8bd2_row6_col3, #T_e8bd2_row6_col4, #T_e8bd2_row6_col5, #T_e8bd2_row6_col6 {
#   background: lightgreen;
# }
# #T_e8bd2_row7_col0, #T_e8bd2_row7_col1, #T_e8bd2_row7_col2, #T_e8bd2_row7_col3, #T_e8bd2_row7_col4, #T_e8bd2_row7_col5, #T_e8bd2_row7_col6, #T_e8bd2_row9_col0, #T_e8bd2_row9_col1, #T_e8bd2_row9_col2, #T_e8bd2_row9_col3, #T_e8bd2_row9_col4, #T_e8bd2_row9_col5, #T_e8bd2_row9_col6, #T_e8bd2_row21_col0, #T_e8bd2_row21_col1, #T_e8bd2_row21_col2, #T_e8bd2_row21_col3, #T_e8bd2_row21_col4, #T_e8bd2_row21_col5, #T_e8bd2_row21_col6, #T_e8bd2_row23_col0, #T_e8bd2_row23_col1, #T_e8bd2_row23_col2, #T_e8bd2_row23_col3, #T_e8bd2_row23_col4, #T_e8bd2_row23_col5, #T_e8bd2_row23_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_e8bd2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8bd2_level0_col0" class="col_heading level0 col0" >shop_id</th>
#       <th id="T_e8bd2_level0_col1" class="col_heading level0 col1" >shop_profile</th>
#       <th id="T_e8bd2_level0_col2" class="col_heading level0 col2" >submission1_62</th>
#       <th id="T_e8bd2_level0_col3" class="col_heading level0 col3" >submission3_66</th>
#       <th id="T_e8bd2_level0_col4" class="col_heading level0 col4" >submission4_58</th>
#       <th id="T_e8bd2_level0_col5" class="col_heading level0 col5" >submission5_62</th>
#       <th id="T_e8bd2_level0_col6" class="col_heading level0 col6" >submission_new</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8bd2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8bd2_row0_col0" class="data row0 col0" >SHOP046</td>
#       <td id="T_e8bd2_row0_col1" class="data row0 col1" >High</td>
#       <td id="T_e8bd2_row0_col2" class="data row0 col2" >High</td>
#       <td id="T_e8bd2_row0_col3" class="data row0 col3" >High</td>
#       <td id="T_e8bd2_row0_col4" class="data row0 col4" >High</td>
#       <td id="T_e8bd2_row0_col5" class="data row0 col5" >High</td>
#       <td id="T_e8bd2_row0_col6" class="data row0 col6" >High</td>
#     </tr>
#     <tr>
#       <th id="T_e8bd2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e8bd2_row1_col0" class="data row1 col0" >SHOP024</td>
#       <td id="T_e8bd2_row1_col1" class="data row1 col1" >Low</td>
#       <td id="T_e8bd2_row1_col2" class="data row1 col2" >Low</td>
#       <td id="T_e8bd2_row1_col3" class="data row1 col3" >Low</td>
#       <td id="T_e8bd2_row1_col4" class="data row1 col4" >Low</td>
#       <td id="T_e8bd2_row1_col5" class="data row1 col5" >Low</td>
#       <td id="T_e8bd2_row1_col6" class="data row1 col6" >Low</td>
#     </tr>
#     <tr>
#       <th id="T_e8bd2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e8bd2_row2_col0" class="data row2 col0" >SHOP023</td>
#       <td id="T_e8bd2_row2_col1" class="data row2 col1" >Low</td>
#       <td id="T_e8bd2_row2_col2" class="data row2 col2" >Low</td>
#       <td id="T_e8bd2_row2_col3" class="data row2 col3" >Low</td>
#       <td id="T_e8bd2_row2_col4" class="data row2 col4" >Low</td>
#       <td id="T_e8bd2_row2_col5" class="data row2 col5" >Low</td>
#       <td id="T_e8bd2_row2_col6" class="data row2 col6" >Low</td>
#     </tr>
#     <tr>
#       <th id="T_e8bd2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e8bd2_row3_col0" class="data row3 col0" >SHOP097</td>
#       <td id="T_e8bd2_row3_col1" class="data row3 col1" >Moderate</td>
#       <td id="T_e8bd2_row3_col2" class="data row3 col2" >Moderate</td>
#       <td id="T_e8bd2_row3_col3" class="data row3 col3" >Moderate</td>
#       <td id="T_e8bd2_row3_col4" class="data row3 col4" >Moderate</td>
#       <td id="T_e8bd2_row3_col5" class="data row3 col5" >Moderate</td>
#       <td id="T_e8bd2_row3_col6" class="data row3 col6" >Moderate</td>
#     </tr>
#     <tr>
#       <th id="T_e8bd2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e8bd2_row4_col0" class="data row4 col0" >SHOP044</td>
#       <td id="T_e8bd2_row4_col1" class="data row4 col1" >High</td>
#       <td id="T_e8bd2_row4_col2" class="data row4 col2" >Moderate</td>
#       <td id="T_e8bd2_row4_col3" class="data row4 col3" >Moderate</td>
#       <td id="T_e8bd2_row4_col4" class="data row4 col4" >High</td>
#       <td id="T_e8bd2_row4_col5" class="data row4 col5" >Moderate</td>
#       <td id="T_e8bd2_row4_col6" class="data row4 col6" >Moderate</td>
#     </tr>
#     <tr>
#       <th id="T_e8bd2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e8bd2_row5_col0" class="data row5 col0" >SHOP030</td>
#       <td id="T_e8bd2_row5_col1" class="data row5 col1" >Low</td>
#       <td id="T_e8bd2_row5_col2" class="data row5 col2" >High</td>
#       <td id="T_e8bd2_row5_col3" class="data row5 col3" >Low</td>
#       <td id="T_e8bd2_row5_col4" class="data row5 col4" >Low</td>
#       <td id="T_e8bd2_row5_col5" class="data row5 col5" >Low</td>
#       <td id="T_e8bd2_row5_col6" class="data row5 col6" >Low</td>
#     </tr>
#     <tr>
#       <th id="T_e8bd2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e8bd2_row6_col0" class="data row6 col0" >SHOP038</td>
#       <td id="T_e8bd2_row6_col1" class="data row6 col1" >Moderate</td>
#       <td id="T_e8bd2_row6_col2" class="data row6 col2" >Moderate</td>
#       <td id="T_e8bd2_row6_col3" class="data row6 col3" >Moderate</td>
#       <td id="T_e8bd2_row6_col4" class="data row6 col4" >High</td>
#       <td id="T_e8bd2_row6_col5" class="data row6 col5" >Moderate</td>
#       <td id="T_e8bd2_row6_col6" class="data row6 col6" >Low</td>
#     </tr>
#     <tr>
#       <th id="T_e8bd2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e8bd2_row7_col0" class="data row7 col0" >SHOP029</td>
#       <td id="T_e8bd2_row7_col1" class="data row7 col1" >High</td>
#       <td id="T_e8bd2_row7_col2" class="data row7 col2" >Moderate</td>
#       <td id="T_e8bd2_row7_col3" class="data row7 col3" >Moderate</td>
#       <td id="T_e8bd2_row7_col4" class="data row7 col4" >Moderate</td>
#       <td id="T_e8bd2_row7_col5" class="data row7 col5" >Moderate</td>
#       <td id="T_e8bd2_row7_col6" class="data row7 col6" >Low</td>
#     </tr>
#     <tr>
#       <th id="T_e8bd2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e8bd2_row8_col0" class="data row8 col0" >SHOP096</td>
#       <td id="T_e8bd2_row8_col1" class="data row8 col1" >Low</td>
#       <td id="T_e8bd2_row8_col2" class="data row8 col2" >Low</td>
#       <td id="T_e8bd2_row8_col3" class="data row8 col3" >Low</td>
#       <td id="T_e8bd2_row8_col4" class="data row8 col4" >Low</td>
#       <td id="T_e8bd2_row8_col5" class="data row8 col5" >Low</td>
#       <td id="T_e8bd2_row8_col6" class="data row8 col6" >Low</td>
#     </tr>
#     <tr>
#       <th id="T_e8bd2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e8bd2_row9_col0" class="data row9 col0" >SHOP092</td>
#       <td id="T_e8bd2_row9_col1" class="data row9 col1" >Low</td>
#       <td id="T_e8bd2_row9_col2" class="data row9 col2" >Moderate</td>
#       <td id="T_e8bd2_row9_col3" class="data row9 col3" >Moderate</td>
#       <td id="T_e8bd2_row9_col4" class="data row9 col4" >Low</td>
#       <td id="T_e8bd2_row9_col5" class="data row9 col5" >Moderate</td>
#       <td id="T_e8bd2_row9_col6" class="data row9 col6" >Low</td>
#     </tr>
#     <tr>
#       <th id="T_e8bd2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e8bd2_row10_col0" class="data row10 col0" >SHOP081</td>
#       <td id="T_e8bd2_row10_col1" class="data row10 col1" >Moderate</td>
#       <td id="T_e8bd2_row10_col2" class="data row10 col2" >Moderate</td>
#       <td id="T_e8bd2_row10_col3" class="data row10 col3" >Moderate</td>
#       <td id="T_e8bd2_row10_col4" class="data row10 col4" >Moderate</td>
#       <td id="T_e8bd2_row10_col5" class="data row10 col5" >Moderate</td>
#       <td id="T_e8bd2_row10_col6" class="data row10 col6" >Moderate</td>
#     </tr>
#     <tr>

# %%
# s_col = s.style.apply(lambda x: ['background: lightgreen' if x.name in [4,6,9]
#                                  'background: lightgreen' elif x.name in [5,7,23]
#                                  else '' for i in x], axis=1)
# # s_col = s.style.apply(lambda x: ['background: lightgreen' if x.name in [5,7,23] 
# #                                  else '' for i in x], axis=1)
# s_col

# %%
# Define a function to highlight specific rows
def highlight_rows(x):
    if x.name in [4, 6, 9]:
        return ['background: lightgreen'] * len(x)
    elif x.name in [5, 7, 23]:
        return ['background: lightblue'] * len(x)
    else:
        return [''] * len(x)

# Apply the function to the dataframe and display it
s_col = s.style.apply(highlight_rows, axis=1)
s_col
# Out:
# <style type="text/css">
# #T_aa6e2_row4_col0, #T_aa6e2_row4_col1, #T_aa6e2_row4_col2, #T_aa6e2_row4_col3, #T_aa6e2_row4_col4, #T_aa6e2_row6_col0, #T_aa6e2_row6_col1, #T_aa6e2_row6_col2, #T_aa6e2_row6_col3, #T_aa6e2_row6_col4, #T_aa6e2_row9_col0, #T_aa6e2_row9_col1, #T_aa6e2_row9_col2, #T_aa6e2_row9_col3, #T_aa6e2_row9_col4 {
#   background: lightgreen;
# }
# #T_aa6e2_row5_col0, #T_aa6e2_row5_col1, #T_aa6e2_row5_col2, #T_aa6e2_row5_col3, #T_aa6e2_row5_col4, #T_aa6e2_row7_col0, #T_aa6e2_row7_col1, #T_aa6e2_row7_col2, #T_aa6e2_row7_col3, #T_aa6e2_row7_col4, #T_aa6e2_row23_col0, #T_aa6e2_row23_col1, #T_aa6e2_row23_col2, #T_aa6e2_row23_col3, #T_aa6e2_row23_col4 {
#   background: lightblue;
# }
# </style>
# <table id="T_aa6e2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa6e2_level0_col0" class="col_heading level0 col0" >shop_id</th>
#       <th id="T_aa6e2_level0_col1" class="col_heading level0 col1" >shop_profile</th>
#       <th id="T_aa6e2_level0_col2" class="col_heading level0 col2" >submission1</th>
#       <th id="T_aa6e2_level0_col3" class="col_heading level0 col3" >submission3</th>
#       <th id="T_aa6e2_level0_col4" class="col_heading level0 col4" >submission4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa6e2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aa6e2_row0_col0" class="data row0 col0" >SHOP046</td>
#       <td id="T_aa6e2_row0_col1" class="data row0 col1" >High</td>
#       <td id="T_aa6e2_row0_col2" class="data row0 col2" >High</td>
#       <td id="T_aa6e2_row0_col3" class="data row0 col3" >High</td>
#       <td id="T_aa6e2_row0_col4" class="data row0 col4" >High</td>
#     </tr>
#     <tr>
#       <th id="T_aa6e2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_aa6e2_row1_col0" class="data row1 col0" >SHOP024</td>
#       <td id="T_aa6e2_row1_col1" class="data row1 col1" >Low</td>
#       <td id="T_aa6e2_row1_col2" class="data row1 col2" >Low</td>
#       <td id="T_aa6e2_row1_col3" class="data row1 col3" >Low</td>
#       <td id="T_aa6e2_row1_col4" class="data row1 col4" >Low</td>
#     </tr>
#     <tr>
#       <th id="T_aa6e2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_aa6e2_row2_col0" class="data row2 col0" >SHOP023</td>
#       <td id="T_aa6e2_row2_col1" class="data row2 col1" >Low</td>
#       <td id="T_aa6e2_row2_col2" class="data row2 col2" >Low</td>
#       <td id="T_aa6e2_row2_col3" class="data row2 col3" >Low</td>
#       <td id="T_aa6e2_row2_col4" class="data row2 col4" >Low</td>
#     </tr>
#     <tr>
#       <th id="T_aa6e2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_aa6e2_row3_col0" class="data row3 col0" >SHOP097</td>
#       <td id="T_aa6e2_row3_col1" class="data row3 col1" >Moderate</td>
#       <td id="T_aa6e2_row3_col2" class="data row3 col2" >Moderate</td>
#       <td id="T_aa6e2_row3_col3" class="data row3 col3" >Moderate</td>
#       <td id="T_aa6e2_row3_col4" class="data row3 col4" >Moderate</td>
#     </tr>
#     <tr>
#       <th id="T_aa6e2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_aa6e2_row4_col0" class="data row4 col0" >SHOP044</td>
#       <td id="T_aa6e2_row4_col1" class="data row4 col1" >High</td>
#       <td id="T_aa6e2_row4_col2" class="data row4 col2" >Moderate</td>
#       <td id="T_aa6e2_row4_col3" class="data row4 col3" >Moderate</td>
#       <td id="T_aa6e2_row4_col4" class="data row4 col4" >High</td>
#     </tr>
#     <tr>
#       <th id="T_aa6e2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_aa6e2_row5_col0" class="data row5 col0" >SHOP030</td>
#       <td id="T_aa6e2_row5_col1" class="data row5 col1" >Low</td>
#       <td id="T_aa6e2_row5_col2" class="data row5 col2" >High</td>
#       <td id="T_aa6e2_row5_col3" class="data row5 col3" >Low</td>
#       <td id="T_aa6e2_row5_col4" class="data row5 col4" >Low</td>
#     </tr>
#     <tr>
#       <th id="T_aa6e2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_aa6e2_row6_col0" class="data row6 col0" >SHOP038</td>
#       <td id="T_aa6e2_row6_col1" class="data row6 col1" >Moderate</td>
#       <td id="T_aa6e2_row6_col2" class="data row6 col2" >Moderate</td>
#       <td id="T_aa6e2_row6_col3" class="data row6 col3" >Moderate</td>
#       <td id="T_aa6e2_row6_col4" class="data row6 col4" >High</td>
#     </tr>
#     <tr>
#       <th id="T_aa6e2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_aa6e2_row7_col0" class="data row7 col0" >SHOP029</td>
#       <td id="T_aa6e2_row7_col1" class="data row7 col1" >High</td>
#       <td id="T_aa6e2_row7_col2" class="data row7 col2" >Moderate</td>
#       <td id="T_aa6e2_row7_col3" class="data row7 col3" >Moderate</td>
#       <td id="T_aa6e2_row7_col4" class="data row7 col4" >Moderate</td>
#     </tr>
#     <tr>
#       <th id="T_aa6e2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_aa6e2_row8_col0" class="data row8 col0" >SHOP096</td>
#       <td id="T_aa6e2_row8_col1" class="data row8 col1" >Low</td>
#       <td id="T_aa6e2_row8_col2" class="data row8 col2" >Low</td>
#       <td id="T_aa6e2_row8_col3" class="data row8 col3" >Low</td>
#       <td id="T_aa6e2_row8_col4" class="data row8 col4" >Low</td>
#     </tr>
#     <tr>
#       <th id="T_aa6e2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_aa6e2_row9_col0" class="data row9 col0" >SHOP092</td>
#       <td id="T_aa6e2_row9_col1" class="data row9 col1" >Low</td>
#       <td id="T_aa6e2_row9_col2" class="data row9 col2" >Moderate</td>
#       <td id="T_aa6e2_row9_col3" class="data row9 col3" >Moderate</td>
#       <td id="T_aa6e2_row9_col4" class="data row9 col4" >Low</td>
#     </tr>
#     <tr>
#       <th id="T_aa6e2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_aa6e2_row10_col0" class="data row10 col0" >SHOP081</td>
#       <td id="T_aa6e2_row10_col1" class="data row10 col1" >Moderate</td>
#       <td id="T_aa6e2_row10_col2" class="data row10 col2" >Moderate</td>
#       <td id="T_aa6e2_row10_col3" class="data row10 col3" >Moderate</td>
#       <td id="T_aa6e2_row10_col4" class="data row10 col4" >Moderate</td>
#     </tr>
#     <tr>
#       <th id="T_aa6e2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_aa6e2_row11_col0" class="data row11 col0" >SHOP076</td>
#       <td id="T_aa6e2_row11_col1" class="data row11 col1" >Low</td>
#       <td id="T_aa6e2_row11_col2" class="data row11 col2" >Low</td>
#       <td id="T_aa6e2_row11_col3" class="data row11 col3" >Low</td>
#       <td id="T_aa6e2_row11_col4" class="data row11 col4" >Low</td>
#     </tr>
#     <tr>
#       <th id="T_aa6e2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_aa6e2_row12_col0" class="data row12 col0" >SHOP080</td>
#       <td id="T_aa6e2_row12_col1" class="data row12 col1" >Low</td>
#       <td id="T_aa6e2_row12_col2" class="data row12 col2" >Low</td>
#       <td id="T_aa6e2_row12_col3" class="data row12 col3" >Low</td>
#       <td id="T_aa6e2_row12_col4" class="data row12 col4" >Low</td>
#     </tr>
#     <tr>
#       <th id="T_aa6e2_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_aa6e2_row13_col0" class="data row13 col0" >SHOP074</td>
#       <td id="T_aa6e2_row13_col1" class="data row13 col1" >Low</td>
#       <td id="T_aa6e2_row13_col2" class="data row13 col2" >Low</td>
#       <td id="T_aa6e2_row13_col3" class="data row13 col3" >Low</td>
#       <td id="T_aa6e2_row13_col4" class="data row13 col4" >Low</td>
#     </tr>
#     <tr>
#       <th id="T_aa6e2_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_aa6e2_row14_col0" class="data row14 col0" >SHOP107</td>
#       <td id="T_aa6e2_row14_col1" class="data row14 col1" >Moderate</td>
#       <td id="T_aa6e2_row14_col2" class="data row14 col2" >Moderate</td>
#       <td id="T_aa6e2_row14_col3" class="data row14 col3" >Moderate</td>
#       <td id="T_aa6e2_row14_col4" class="data row14 col4" >Moderate</td>
#     </tr>
#     <tr>
#       <th id="T_aa6e2_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_aa6e2_row15_col0" class="data row15 col0" >SHOP108</td>

# %%
s5['shop_profile'].value_counts()
# Out:
# Low         11
# Moderate     8
# High         5
# Name: shop_profile, dtype: int64

# %%
s5['shop_profile'].value_counts()
# Out:
# Low         11
# Moderate     9
# High         4
# Name: shop_profile, dtype: int64

# %%
s4['shop_profile'].value_counts()
# Out:
# Low         13
# High         6
# Moderate     5
# Name: shop_profile, dtype: int64

# %%
s3['shop_profile'].value_counts()
# Out:
# Low         12
# Moderate     8
# High         4
# Name: shop_profile, dtype: int64

# %%
s1['shop_profile'].value_counts()
# Out:
# Low         11
# Moderate     8
# High         5
# Name: shop_profile, dtype: int64

# %%
s['shop_profile'].value_counts()
# Out:
# Low         12
# High         6
# Moderate     6
# Name: shop_profile, dtype: int64
